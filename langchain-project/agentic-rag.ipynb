# %%
# %pip install langchain langgraph langchain_community langchain_huggingface chromadb sentence-transformers tiktoken transformers
# Out:
# Requirement already satisfied: langchain in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (0.3.13)
# Requirement already satisfied: langgraph in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (0.2.60)
# Requirement already satisfied: langchain_community in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (0.3.12)
# Requirement already satisfied: langchain_huggingface in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (0.1.2)
# Requirement already satisfied: chromadb in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (0.5.23)
# Requirement already satisfied: sentence-transformers in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (3.3.1)
# Requirement already satisfied: tiktoken in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (0.8.0)
# Requirement already satisfied: transformers in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (4.46.3)
# Requirement already satisfied: PyYAML>=5.3 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from langchain) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from langchain) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from langchain) (3.11.11)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.26 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from langchain) (0.3.27)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.3 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from langchain) (0.3.4)
# Requirement already satisfied: langsmith<0.3,>=0.1.17 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from langchain) (0.2.4)
# Requirement already satisfied: numpy<3,>=1.26.2 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from langchain) (2.2.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from langchain) (2.10.4)
# Requirement already satisfied: requests<3,>=2 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from langchain) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from langchain) (9.0.0)
# Requirement already satisfied: langgraph-checkpoint<3.0.0,>=2.0.4 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from langgraph) (2.0.9)
# Requirement already satisfied: langgraph-sdk<0.2.0,>=0.1.42 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from langgraph) (0.1.48)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from langchain_community) (0.6.7)
# Requirement already satisfied: httpx-sse<0.5.0,>=0.4.0 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from langchain_community) (0.4.0)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from langchain_community) (2.7.0)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from langchain_huggingface) (0.27.0)
# Requirement already satisfied: tokenizers>=0.19.1 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from langchain_huggingface) (0.20.3)
# Requirement already satisfied: build>=1.0.3 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from chromadb) (1.2.2.post1)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from chromadb) (0.7.6)
# Requirement already satisfied: fastapi>=0.95.2 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from chromadb) (0.115.6)
# Requirement already satisfied: uvicorn>=0.18.3 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.34.0)
# Requirement already satisfied: posthog>=2.4.0 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from chromadb) (3.7.4)
# Requirement already satisfied: typing_extensions>=4.5.0 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from chromadb) (4.12.2)
# Requirement already satisfied: onnxruntime>=1.14.1 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from chromadb) (1.20.1)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from chromadb) (1.29.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from chromadb) (1.29.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from chromadb) (0.50b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from chromadb) (1.29.0)
# Requirement already satisfied: pypika>=0.48.9 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from chromadb) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from chromadb) (6.4.5)
# Requirement already satisfied: grpcio>=1.58.0 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from chromadb) (1.68.1)
# Requirement already satisfied: bcrypt>=4.0.1 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from chromadb) (4.2.1)
# Requirement already satisfied: typer>=0.9.0 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from chromadb) (0.15.1)
# Requirement already satisfied: kubernetes>=28.1.0 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from chromadb) (31.0.0)
# Requirement already satisfied: mmh3>=4.0.1 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from chromadb) (5.0.1)
# Requirement already satisfied: orjson>=3.9.12 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from chromadb) (3.10.12)
# Requirement already satisfied: httpx>=0.27.0 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from chromadb) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from chromadb) (13.9.4)
# Requirement already satisfied: torch>=1.11.0 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from sentence-transformers) (2.4.1)
# Requirement already satisfied: scikit-learn in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from sentence-transformers) (1.6.0)
# Requirement already satisfied: scipy in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from sentence-transformers) (1.14.1)
# Requirement already satisfied: Pillow in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from sentence-transformers) (11.0.0)
# Requirement already satisfied: regex>=2022.1.18 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from tiktoken) (2024.11.6)
# Requirement already satisfied: filelock in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from transformers) (3.16.1)
# Requirement already satisfied: packaging>=20.0 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from transformers) (24.2)
# Requirement already satisfied: safetensors>=0.4.1 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from transformers) (0.4.5)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.18.3)
# Requirement already satisfied: pyproject_hooks in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (3.23.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (0.9.0)
# Requirement already satisfied: starlette<0.42.0,>=0.40.0 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from fastapi>=0.95.2->chromadb) (0.41.3)
# Requirement already satisfied: anyio in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from httpx>=0.27.0->chromadb) (4.7.0)
# Requirement already satisfied: certifi in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from httpx>=0.27.0->chromadb) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from httpx>=0.27.0->chromadb) (1.0.7)
# Requirement already satisfied: idna in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from httpx>=0.27.0->chromadb) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.14.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from huggingface-hub>=0.23.0->langchain_huggingface) (2024.10.0)
# Requirement already satisfied: six>=1.9.0 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb) (2.37.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests-oauthlib in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb) (2.2.3)
# Requirement already satisfied: durationpy>=0.7 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb) (0.9)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from langchain-core<0.4.0,>=0.3.26->langchain) (1.33)
# Requirement already satisfied: msgpack<2.0.0,>=1.1.0 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from langgraph-checkpoint<3.0.0,>=2.0.4->langgraph) (1.1.0)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from langsmith<0.3,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: coloredlogs in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb) (24.3.25)
# Requirement already satisfied: protobuf in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb) (5.29.2)
# Requirement already satisfied: sympy in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb) (1.13.3)
# Requirement already satisfied: deprecated>=1.2.6 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from opentelemetry-api>=1.2.0->chromadb) (1.2.15)
# Requirement already satisfied: importlib-metadata<=8.5.0,>=6.0 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.5.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.66.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.29.0 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.29.0)
# Requirement already satisfied: opentelemetry-proto==1.29.0 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.29.0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.50b0 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.50b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.50b0 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.50b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.50b0 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.50b0)
# Requirement already satisfied: opentelemetry-util-http==0.50b0 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.50b0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from opentelemetry-instrumentation==0.50b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.17.0)
# Requirement already satisfied: asgiref~=3.0 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from opentelemetry-instrumentation-asgi==0.50b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from posthog>=2.4.0->chromadb) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.27.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain_community) (1.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from requests<3,>=2->langchain) (3.4.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from rich>=10.11.0->chromadb) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from rich>=10.11.0->chromadb) (2.18.0)
# Requirement already satisfied: greenlet!=0.4.17 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.1.1)
# Requirement already satisfied: networkx in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: jinja2 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Requirement already satisfied: setuptools in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (75.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (3.0.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.11.0->sentence-transformers) (12.6.85)
# Requirement already satisfied: click>=8.0.0 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from typer>=0.9.0->chromadb) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.4)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.3)
# Requirement already satisfied: websockets>=10.4 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (14.1)
# Requirement already satisfied: joblib>=1.2.0 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Requirement already satisfied: zipp>=3.20 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from importlib-metadata<=8.5.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.21.0)
# Requirement already satisfied: jsonpointer>=1.9 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.26->langchain) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: sniffio>=1.1 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from anyio->httpx>=0.27.0->chromadb) (1.3.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community) (1.0.0)
# Requirement already satisfied: humanfriendly>=9.1 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /home/codespace/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_community.document_loaders import WebBaseLoader
from langchain_community.vectorstores import Chroma
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain.embeddings.huggingface import HuggingFaceEmbeddings

urls = [
    "https://lilianweng.github.io/posts/2023-06-23-agent/",
    "https://lilianweng.github.io/posts/2023-03-15-prompt-engineering/",
    "https://lilianweng.github.io/posts/2023-10-25-adv-attack-llm/",
]

docs = [WebBaseLoader(url).load() for url in urls]
docs_list = [item for sublist in docs for item in sublist]

text_splitter = RecursiveCharacterTextSplitter(
    # Set a really small chunk size, just to show.
    chunk_size=100,
    chunk_overlap=20,
    length_function=len,
    is_separator_regex=False,
)
doc_splits = text_splitter.split_documents(docs_list)


embedding= HuggingFaceEmbeddings(model_name="BAAI/bge-small-en-v1.5")
# Add to vectorDB
vectorstore = Chroma.from_documents(
    documents=doc_splits,
    collection_name="rag-chroma",
    embedding = embedding,
)
retriever = vectorstore.as_retriever()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages/langchain_community/embeddings/huggingface.py:84, in HuggingFaceEmbeddings.__init__(self, **kwargs)
#      83 try:
# ---> 84     import sentence_transformers
#      86 except ImportError as exc:
#
# File ~/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages/sentence_transformers/__init__.py:9
#       7 import os
# ----> 9 from sentence_transformers.backend import (
#      10     export_dynamic_quantized_onnx_model,
#      11     export_optimized_onnx_model,
#      12     export_static_quantized_openvino_model,
#      13 )
#      14 from sentence_transformers.cross_encoder.CrossEncoder import CrossEncoder
#
# File ~/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages/sentence_transformers/backend.py:11
#       9 import huggingface_hub
# ---> 11 from sentence_transformers.util import disable_datasets_caching, is_datasets_available
#      13 logger = logging.getLogger(__name__)
#
# File ~/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages/sentence_transformers/util.py:19
#      18 from huggingface_hub import hf_hub_download, snapshot_download
# ---> 19 from torch import Tensor, device
#      20 from tqdm import trange
#
# ImportError: cannot import name 'Tensor' from 'torch' (unknown location)
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# Cell In[12], line 25
#      15 text_splitter = RecursiveCharacterTextSplitter(
#      16     # Set a really small chunk size, just to show.
#      17     chunk_size=100,
#    (...)
#      20     is_separator_regex=False,
#      21 )
#      22 doc_splits = text_splitter.split_documents(docs_list)
# ---> 25 embedding= HuggingFaceEmbeddings(model_name="BAAI/bge-small-en-v1.5")
#      26 # Add to vectorDB
#      27 vectorstore = Chroma.from_documents(
#      28     documents=doc_splits,
#      29     collection_name="rag-chroma",
#      30     embedding = embedding,
#      31 )
#
# File ~/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages/langchain_core/_api/deprecation.py:216, in deprecated.<locals>.deprecate.<locals>.finalize.<locals>.warn_if_direct_instance(self, *args, **kwargs)
#     214     warned = True
#     215     emit_warning()
# --> 216 return wrapped(self, *args, **kwargs)
#
# File ~/.cache/pypoetry/virtualenvs/agentic_rag-i74kL8d5-py3.12/lib/python3.12/site-packages/langchain_community/embeddings/huggingface.py:87, in HuggingFaceEmbeddings.__init__(self, **kwargs)
#      84     import sentence_transformers
#      86 except ImportError as exc:
# ---> 87     raise ImportError(
#      88         "Could not import sentence_transformers python package. "
#      89         "Please install it with `pip install sentence-transformers`."
#      90     ) from exc
#      92 self.client = sentence_transformers.SentenceTransformer(
#      93     self.model_name, cache_folder=self.cache_folder, **self.model_kwargs
#      94 )
#
# ImportError: Could not import sentence_transformers python package. Please install it with `pip install sentence-transformers`.
